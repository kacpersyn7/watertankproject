# %% [markdown]
# # Import

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from load_data import load_data

# %%
my_data = load_data(path='/home/kacper/experiments/')

# %%
experiments = my_data.build_data_frame()

# %% [markdown]
# # Explore

# %%
experiments.describe()
# Out:
#                  009                                               \
#                   h1             h2             h3             v1
# count  180000.000000  180000.000000  180000.000000  180000.000000
# mean       10.201288      11.086021       9.874098       0.166650
# std         7.574436       7.434866       6.828174       0.357408
# min        -0.058162       0.291414      -0.116088       0.000000
# 25%         3.943614       4.912427       4.566613       0.000000
# 50%         9.920952       6.731336       5.946778       0.000000
# 75%        14.918951      17.300675      14.835695       0.000000
# max        23.935613      28.263291      27.224315       1.000000
#
#                                                               013  \
#                   v2             v3              u             h1
# count  180000.000000  180000.000000  180000.000000  180000.000000
# mean        0.066667       0.133333       0.725000      10.876839
# ...

# %%
experiments.head()
# Out:
#            009                                                013            \
#             h1        h2        h3   v1   v2   v3     u        h1        h2
# 0.00 -0.041277  0.307800 -0.099658  0.0  0.0  0.0  0.65 -0.062731  0.276697
# 0.01 -0.041277  0.307800 -0.099658  0.0  0.0  0.0  0.65 -0.062731  0.260341
# 0.02 -0.041277  0.291414 -0.116088  0.0  0.0  0.0  0.65 -0.062731  0.276697
# 0.03 -0.041277  0.324187 -0.066797  0.0  0.0  0.0  0.65 -0.029018  0.293052
# 0.04 -0.007507  0.307800 -0.099658  0.0  0.0  0.0  0.65 -0.012162  0.293052
#
#                 ...   004                  006                                \
#             h3  ...    v2   v3     u        h1        h2        h3   v1   v2
# 0.00 -0.055090  ...   0.0  0.0  0.65  0.243917  0.307636  0.107052  0.0  0.0
# 0.01 -0.055090  ...   0.0  0.0  0.65  0.227213  0.291216  0.139870  0.0  0.0
# 0.02 -0.055090  ...   0.0  0.0  0.65  0.243917  0.307636  0.107052  0.0  0.0
# ...

# %% [markdown]
# # Experiment with event

# %%
experiments['004'].plot(subplots=True, figsize=(20,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e79465978>,
# ...
#       dtype=object)

# %%
event_part = experiments['004'][0:500]
event_part = event_part[lambda df: df.v1 > 0.5]

# %%
features = ['h1', 'h2', 'h3']

# %%
event_part[features].plot(figsize=(20,10))

# %%
event_part[features].boxplot(figsize=(10,10))

# %%
event_part[features].hist(figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e739df048>,
# ...
#       dtype=object)

# %%
corr_event_res = event_part[features].corr()
corr_event_res["h1"].sort_values(ascending=False)
# Out:
# h1    1.000000
# h2    0.366038
# h3   -0.202846
# Name: h1, dtype: float64

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(event_part[features], figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e73827128>,
# ...
#       dtype=object)

# %%
val_data = experiments['004'][800:1100]

# %%
val_data[features].plot()

# %%
corr_val_res = val_data[features].corr()
corr_val_res["h1"].sort_values(ascending=False)
# Out:
# h1    1.000000
# h2    0.875271
# h3    0.793783
# Name: h1, dtype: float64

# %%
scatter_matrix(val_data[features], figsize=(15, 15), alpha=0.2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e734b3c18>,
# ...
#       dtype=object)

# %% [markdown]
# # Comparison

# %%
val_data.describe()
# Out:
#                  h1            h2            h3       v1       v2  \
# count  30001.000000  30001.000000  30001.000000  30001.0  30001.0
# mean      17.724531     19.740081     20.859141      0.0      0.0
# std        2.961157      2.894024      2.797820      0.0      0.0
# min       13.949931     15.278689     13.741806      0.0      0.0
# 25%       14.959613     16.639344     18.336520      0.0      0.0
# 50%       16.474136     20.180328     21.745501      0.0      0.0
# 75%       20.798940     22.409836     23.112388      0.0      0.0
# max       23.070725     25.032787     26.768397      0.0      0.0
#
#                  v3             u
# count  30001.000000  30001.000000
# mean       0.005558      0.783332
# std        0.024225      0.047141
# min        0.000000      0.750000
# 25%        0.000000      0.750000
# 50%        0.000000      0.750000
# 75%        0.000000      0.850000
# max        0.166667      0.850000

# %%
event_part.describe()
# Out:
#                  h1            h2            h3            v1       v2  \
# count  11999.000000  11999.000000  11999.000000  11999.000000  11999.0
# mean       1.117329      6.187990      5.807944      0.999917      0.0
# std        0.808675      1.305048      0.625302      0.004811      0.0
# min        0.437020      4.147541      4.700594      0.666667      0.0
# 25%        0.739925      5.196721      5.293461      1.000000      0.0
# 50%        0.824065      5.540984      5.688705      1.000000      0.0
# 75%        0.958689      7.393443      6.429788      1.000000      0.0
# max        4.778653      8.786885      6.874437      1.000000      0.0
#
#             v3             u
# count  11999.0  1.199900e+04
# mean       0.0  6.500000e-01
# std        0.0  1.391167e-13
# min        0.0  6.500000e-01
# 25%        0.0  6.500000e-01
# 50%        0.0  6.500000e-01
# 75%        0.0  6.500000e-01
# max        0.0  6.500000e-01
